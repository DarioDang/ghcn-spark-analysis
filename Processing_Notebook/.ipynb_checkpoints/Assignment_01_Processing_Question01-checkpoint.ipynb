# %% [markdown]
# ### Spark notebook ###
#
# This notebook will only work in a Jupyter session running on `mathmadslinux2p`.
#
# You can start your own Jupyter session on `mathmadslinux2p` and open this notebook in Chrome on the MADS Windows server by
#
# **Steps**
#
# 1. Login to the MADS Windows server using https://mathportal.canterbury.ac.nz/.
# 2. Download or copy this notebook to your home directory.
# 3. Open powershell and run `ssh mathmadslinux2p`.
# 4. Run `start_pyspark_notebook` or `/opt/anaconda3/bin/jupyter-notebook --ip 132.181.129.68 --port $((8000 + $((RANDOM % 999))))`.
# 5. Copy / paste the url provided in the shell window into Chrome on the MADS Windows server.
# 6. Open the notebook from the Jupyter root directory (which is your home directory).
# 7. Run `start_spark()` to start a spark session in the notebook.
# 8. Run `stop_spark()` before closing the notebook or kill your spark application by hand using the link in the Spark UI.

# %%
# Run this cell to import pyspark and to define start_spark() and stop_spark()

import findspark

findspark.init()

import getpass
import pandas
import pyspark
import random
import re

from IPython.display import display, HTML
from pyspark import SparkContext
from pyspark.sql import SparkSession


# Functions used below

def username():
    """Get username with any domain information removed.
    """

    return re.sub('@.*', '', getpass.getuser())


def dict_to_html(d):
    """Convert a Python dictionary into a two column table for display.
    """

    html = []

    html.append(f'<table width="100%" style="width:100%; font-family: monospace;">')
    for k, v in d.items():
        html.append(f'<tr><td style="text-align:left;">{k}</td><td>{v}</td></tr>')
    html.append(f'</table>')

    return ''.join(html)


def show_as_html(df, n=20):
    """Leverage existing pandas jupyter integration to show a spark dataframe as html.
    
    Args:
        n (int): number of rows to show (default: 20)
    """

    display(df.limit(n).toPandas())

    
def display_spark():
    """Display the status of the active Spark session if one is currently running.
    """
    
    if 'spark' in globals() and 'sc' in globals():

        name = sc.getConf().get("spark.app.name")
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:green">active</span></b>, look for <code>{name}</code> under the running applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'<li><a href="{sc.uiWebUrl}" target="_blank">Spark Application UI</a></li>',
            f'</ul>',
            f'<p><b>Config</b></p>',
            dict_to_html(dict(sc.getConf().getAll())),
            f'<p><b>Notes</b></p>',
            f'<ul>',
            f'<li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li>',
            f'<li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>{name}</code> by hand using the link in the Spark UI.</li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))
        
    else:
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>{username() + " (jupyter)"}</code> is under the completed applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))


# Functions to start and stop spark

def start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1):
    """Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
    
    Args:
        executor_instances (int): number of executors (default: 2)
        executor_cores (int): number of cores per executor (default: 1)
        worker_memory (float): worker memory (default: 1)
        master_memory (float): master memory (default: 1)
    """

    global spark
    global sc

    user = username()
    
    cores = executor_instances * executor_cores
    partitions = cores * 4
    port = 4000 + random.randint(1, 999)

    spark = (
        SparkSession.builder
        .master("spark://masternode2:7077")
        .config("spark.driver.extraJavaOptions", f"-Dderby.system.home=/tmp/{user}/spark/")
        .config("spark.dynamicAllocation.enabled", "false")
        .config("spark.executor.instances", str(executor_instances))
        .config("spark.executor.cores", str(executor_cores))
        .config("spark.cores.max", str(cores))
        .config("spark.executor.memory", f"{worker_memory}g")
        .config("spark.driver.memory", f"{master_memory}g")
        .config("spark.driver.maxResultSize", "0")
        .config("spark.sql.shuffle.partitions", str(partitions))
        .config("spark.ui.port", str(port))
        .appName(user + " (jupyter)")
        .getOrCreate()
    )
    sc = SparkContext.getOrCreate()
    
    display_spark()

    
def stop_spark():
    """Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
    """

    global spark
    global sc

    if 'spark' in globals() and 'sc' in globals():

        spark.stop()

        del spark
        del sc

    display_spark()


# Make css changes to improve spark output readability

html = [
    '<style>',
    'pre { white-space: pre !important; }',
    'table.dataframe td { white-space: nowrap !important; }',
    'table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }',
    '</style>',
]
display(HTML(''.join(html)))
# Out:
# <style>pre { white-space: pre !important; }table.dataframe td { white-space: nowrap !important; }table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }</style>

# %% [markdown]
# ## Start Spark

# %%
# Run this cell to start a spark session in this notebook

start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1)
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:green">active</span></b>, look for <code>kda115 (jupyter)</code> under the running applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li><li><a href="http://mathmadslinux2p.canterbury.ac.nz:4612" target="_blank">Spark Application UI</a></li></ul><p><b>Config</b></p><table width="100%" style="width:100%; font-family: monospace;"><tr><td style="text-align:left;">spark.app.name</td><td>kda115 (jupyter)</td></tr><tr><td style="text-align:left;">spark.dynamicAllocation.enabled</td><td>false</td></tr><tr><td style="text-align:left;">spark.app.startTime</td><td>1724283017000</td></tr><tr><td style="text-align:left;">spark.master</td><td>spark://masternode2:7077</td></tr><tr><td style="text-align:left;">spark.app.id</td><td>app-20240822113018-0957</td></tr><tr><td style="text-align:left;">spark.executor.id</td><td>driver</td></tr><tr><td style="text-align:left;">spark.driver.memory</td><td>1g</td></tr><tr><td style="text-align:left;">spark.driver.host</td><td>mathmadslinux2p.canterbury.ac.nz</td></tr><tr><td style="text-align:left;">spark.executor.memory</td><td>1g</td></tr><tr><td style="text-align:left;">spark.rdd.compress</td><td>True</td></tr><tr><td style="text-align:left;">spark.executor.instances</td><td>2</td></tr><tr><td style="text-align:left;">spark.sql.warehouse.dir</td><td>file:/users/home/kda115/Spark/Assignment/spark-warehouse</td></tr><tr><td style="text-align:left;">spark.serializer.objectStreamReset</td><td>100</td></tr><tr><td style="text-align:left;">spark.driver.maxResultSize</td><td>0</td></tr><tr><td style="text-align:left;">spark.cores.max</td><td>2</td></tr><tr><td style="text-align:left;">spark.submit.pyFiles</td><td></td></tr><tr><td style="text-align:left;">spark.executor.cores</td><td>1</td></tr><tr><td style="text-align:left;">spark.submit.deployMode</td><td>client</td></tr><tr><td style="text-align:left;">spark.driver.extraJavaOptions</td><td>-Dderby.system.home=/tmp/kda115/spark/</td></tr><tr><td style="text-align:left;">spark.ui.port</td><td>4612</td></tr><tr><td style="text-align:left;">spark.sql.shuffle.partitions</td><td>8</td></tr><tr><td style="text-align:left;">spark.driver.port</td><td>45781</td></tr><tr><td style="text-align:left;">spark.ui.showConsoleProgress</td><td>true</td></tr></table><p><b>Notes</b></p><ul><li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li><li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>kda115 (jupyter)</code> by hand using the link in the Spark UI.</li></ul>

# %% [markdown]
# ## Processing

# %% [markdown]
# ## Question 01

# %% [markdown]
# ### a. How is data structured?

# %%
# List all files and directories in the HDFS 
! hdfs dfs -ls hdfs:///data/ghcnd
# Out:
# Found 5 items
# drwxr-xr-x   - jsw93 jsw93          0 2024-08-21 12:34 hdfs:///data/ghcnd/daily
# -rw-r--r--   8 jsw93 jsw93       3659 2024-08-13 14:44 hdfs:///data/ghcnd/ghcnd-countries.txt
# -rw-r--r--   8 jsw93 jsw93   34791732 2024-08-13 14:44 hdfs:///data/ghcnd/ghcnd-inventory.txt
# -rw-r--r--   8 jsw93 jsw93       1086 2024-08-13 14:44 hdfs:///data/ghcnd/ghcnd-states.txt
# -rw-r--r--   8 jsw93 jsw93   11007484 2024-08-13 14:44 hdfs:///data/ghcnd/ghcnd-stations.txt

# %% [markdown]
# ### b. How many years are contained daily, and how does the size of the data change?

# %% [markdown]
# #### b.1 How many years are contained daily

# %%
# List the files in the daily directory to identify years
! hdfs dfs -ls hdfs:///data/ghcnd/daily/
# Out:
# Found 263 items
# -rw-r--r--   8 jsw93 jsw93    1897634 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1750.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3358 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1763.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3327 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1764.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3335 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1765.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3344 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1766.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3356 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1767.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3325 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1768.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3418 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1769.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3357 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1770.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3373 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1771.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3419 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1772.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3368 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1773.csv.gz
# -rw-r--r--   8 jsw93 jsw93       3393 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1774.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6365 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1775.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6425 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1776.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6424 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1777.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6240 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1778.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6144 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1779.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6245 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1780.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7799 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1781.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7808 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1782.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7920 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1783.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7946 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1784.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7804 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1785.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7891 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1786.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6336 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1787.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6394 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1788.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7773 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1789.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7786 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1790.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7734 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1791.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7806 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1792.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6342 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1793.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7770 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1794.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7843 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1795.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7821 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1796.csv.gz
# -rw-r--r--   8 jsw93 jsw93       9239 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1797.csv.gz
# -rw-r--r--   8 jsw93 jsw93       9290 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1798.csv.gz
# -rw-r--r--   8 jsw93 jsw93       6351 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1799.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7783 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1800.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7801 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1801.csv.gz
# -rw-r--r--   8 jsw93 jsw93       9195 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1802.csv.gz
# -rw-r--r--   8 jsw93 jsw93       7892 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1803.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8727 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1804.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8901 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1805.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8598 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1806.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8725 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1807.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8928 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1808.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8778 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1809.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8829 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1810.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8932 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1811.csv.gz
# -rw-r--r--   8 jsw93 jsw93       8993 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1812.csv.gz
# -rw-r--r--   8 jsw93 jsw93       9264 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1813.csv.gz
# -rw-r--r--   8 jsw93 jsw93      10833 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1814.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13884 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1815.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13865 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1816.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13758 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1817.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13758 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1818.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13690 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1819.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13997 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1820.csv.gz
# -rw-r--r--   8 jsw93 jsw93      13792 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1821.csv.gz
# -rw-r--r--   8 jsw93 jsw93      14049 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1822.csv.gz
# -rw-r--r--   8 jsw93 jsw93      14745 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1823.csv.gz
# -rw-r--r--   8 jsw93 jsw93      18035 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1824.csv.gz
# -rw-r--r--   8 jsw93 jsw93      18101 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1825.csv.gz
# -rw-r--r--   8 jsw93 jsw93      18403 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1826.csv.gz
# -rw-r--r--   8 jsw93 jsw93      20855 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1827.csv.gz
# -rw-r--r--   8 jsw93 jsw93      20981 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1828.csv.gz
# -rw-r--r--   8 jsw93 jsw93      21141 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1829.csv.gz
# -rw-r--r--   8 jsw93 jsw93      21306 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1830.csv.gz
# -rw-r--r--   8 jsw93 jsw93      21319 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1831.csv.gz
# -rw-r--r--   8 jsw93 jsw93      22435 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1832.csv.gz
# -rw-r--r--   8 jsw93 jsw93      27286 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1833.csv.gz
# -rw-r--r--   8 jsw93 jsw93      27098 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1834.csv.gz
# -rw-r--r--   8 jsw93 jsw93      27516 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1835.csv.gz
# -rw-r--r--   8 jsw93 jsw93      29812 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1836.csv.gz
# -rw-r--r--   8 jsw93 jsw93      29339 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1837.csv.gz
# -rw-r--r--   8 jsw93 jsw93      31700 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1838.csv.gz
# -rw-r--r--   8 jsw93 jsw93      29587 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1839.csv.gz
# -rw-r--r--   8 jsw93 jsw93      35991 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1840.csv.gz
# -rw-r--r--   8 jsw93 jsw93      36990 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1841.csv.gz
# -rw-r--r--   8 jsw93 jsw93      39432 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1842.csv.gz
# -rw-r--r--   8 jsw93 jsw93      39397 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1843.csv.gz
# -rw-r--r--   8 jsw93 jsw93      43316 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1844.csv.gz
# -rw-r--r--   8 jsw93 jsw93      47105 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1845.csv.gz
# -rw-r--r--   8 jsw93 jsw93      44647 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1846.csv.gz
# -rw-r--r--   8 jsw93 jsw93      46181 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1847.csv.gz
# -rw-r--r--   8 jsw93 jsw93      45048 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1848.csv.gz
# -rw-r--r--   8 jsw93 jsw93      47371 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1849.csv.gz
# -rw-r--r--   8 jsw93 jsw93      47552 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1850.csv.gz
# -rw-r--r--   8 jsw93 jsw93      55032 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1851.csv.gz
# -rw-r--r--   8 jsw93 jsw93      58865 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1852.csv.gz
# -rw-r--r--   8 jsw93 jsw93      59631 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1853.csv.gz
# -rw-r--r--   8 jsw93 jsw93      59258 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1854.csv.gz
# -rw-r--r--   8 jsw93 jsw93      64887 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1855.csv.gz
# -rw-r--r--   8 jsw93 jsw93      76292 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1856.csv.gz
# -rw-r--r--   8 jsw93 jsw93      83128 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1857.csv.gz
# -rw-r--r--   8 jsw93 jsw93     115535 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1858.csv.gz
# -rw-r--r--   8 jsw93 jsw93     128727 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1859.csv.gz
# -rw-r--r--   8 jsw93 jsw93     137798 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1860.csv.gz
# -rw-r--r--   8 jsw93 jsw93     143140 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1861.csv.gz
# -rw-r--r--   8 jsw93 jsw93     137811 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1862.csv.gz
# -rw-r--r--   8 jsw93 jsw93     155000 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1863.csv.gz
# -rw-r--r--   8 jsw93 jsw93     159466 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1864.csv.gz
# -rw-r--r--   8 jsw93 jsw93     160531 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1865.csv.gz
# -rw-r--r--   8 jsw93 jsw93     208166 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1866.csv.gz
# -rw-r--r--   8 jsw93 jsw93     249331 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1867.csv.gz
# -rw-r--r--   8 jsw93 jsw93     262203 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1868.csv.gz
# -rw-r--r--   8 jsw93 jsw93     303439 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1869.csv.gz
# -rw-r--r--   8 jsw93 jsw93     348087 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1870.csv.gz
# -rw-r--r--   8 jsw93 jsw93     458274 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1871.csv.gz
# -rw-r--r--   8 jsw93 jsw93     621839 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1872.csv.gz
# -rw-r--r--   8 jsw93 jsw93     695994 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1873.csv.gz
# -rw-r--r--   8 jsw93 jsw93     778728 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1874.csv.gz
# -rw-r--r--   8 jsw93 jsw93     846523 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1875.csv.gz
# -rw-r--r--   8 jsw93 jsw93     917654 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1876.csv.gz
# -rw-r--r--   8 jsw93 jsw93    1023460 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1877.csv.gz
# -rw-r--r--   8 jsw93 jsw93    1216615 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1878.csv.gz
# -rw-r--r--   8 jsw93 jsw93    1395616 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1879.csv.gz
# -rw-r--r--   8 jsw93 jsw93    1757729 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1880.csv.gz
# -rw-r--r--   8 jsw93 jsw93    2092465 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1881.csv.gz
# -rw-r--r--   8 jsw93 jsw93    2383564 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1882.csv.gz
# -rw-r--r--   8 jsw93 jsw93    2632229 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1883.csv.gz
# -rw-r--r--   8 jsw93 jsw93    3148341 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1884.csv.gz
# -rw-r--r--   8 jsw93 jsw93    3573928 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1885.csv.gz
# -rw-r--r--   8 jsw93 jsw93    3917845 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1886.csv.gz
# -rw-r--r--   8 jsw93 jsw93    4408365 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1887.csv.gz
# -rw-r--r--   8 jsw93 jsw93    4747403 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1888.csv.gz
# -rw-r--r--   8 jsw93 jsw93    5151995 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1889.csv.gz
# -rw-r--r--   8 jsw93 jsw93    5617873 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1890.csv.gz
# -rw-r--r--   8 jsw93 jsw93    5888217 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1891.csv.gz
# -rw-r--r--   8 jsw93 jsw93    6795075 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1892.csv.gz
# -rw-r--r--   8 jsw93 jsw93   12518572 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1893.csv.gz
# -rw-r--r--   8 jsw93 jsw93   13382901 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1894.csv.gz
# -rw-r--r--   8 jsw93 jsw93   14452960 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1895.csv.gz
# -rw-r--r--   8 jsw93 jsw93   15584899 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1896.csv.gz
# -rw-r--r--   8 jsw93 jsw93   16835983 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1897.csv.gz
# -rw-r--r--   8 jsw93 jsw93   17569286 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1898.csv.gz
# -rw-r--r--   8 jsw93 jsw93   18262483 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1899.csv.gz
# -rw-r--r--   8 jsw93 jsw93   19510560 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1900.csv.gz
# -rw-r--r--   8 jsw93 jsw93   24810670 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1901.csv.gz
# -rw-r--r--   8 jsw93 jsw93   25744407 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1902.csv.gz
# -rw-r--r--   8 jsw93 jsw93   26280511 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1903.csv.gz
# -rw-r--r--   8 jsw93 jsw93   27134118 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1904.csv.gz
# -rw-r--r--   8 jsw93 jsw93   28543152 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1905.csv.gz
# -rw-r--r--   8 jsw93 jsw93   29172099 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1906.csv.gz
# -rw-r--r--   8 jsw93 jsw93   29899433 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1907.csv.gz
# -rw-r--r--   8 jsw93 jsw93   30600786 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1908.csv.gz
# -rw-r--r--   8 jsw93 jsw93   32222415 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1909.csv.gz
# -rw-r--r--   8 jsw93 jsw93   33303323 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1910.csv.gz
# -rw-r--r--   8 jsw93 jsw93   34508905 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1911.csv.gz
# -rw-r--r--   8 jsw93 jsw93   35809087 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1912.csv.gz
# -rw-r--r--   8 jsw93 jsw93   36755413 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1913.csv.gz
# -rw-r--r--   8 jsw93 jsw93   37942089 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1914.csv.gz
# -rw-r--r--   8 jsw93 jsw93   39102164 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1915.csv.gz
# -rw-r--r--   8 jsw93 jsw93   40434982 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1916.csv.gz
# -rw-r--r--   8 jsw93 jsw93   40655290 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1917.csv.gz
# -rw-r--r--   8 jsw93 jsw93   39716531 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1918.csv.gz
# -rw-r--r--   8 jsw93 jsw93   39254184 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1919.csv.gz
# -rw-r--r--   8 jsw93 jsw93   39491562 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1920.csv.gz
# -rw-r--r--   8 jsw93 jsw93   39748975 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1921.csv.gz
# -rw-r--r--   8 jsw93 jsw93   40469703 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1922.csv.gz
# -rw-r--r--   8 jsw93 jsw93   41210805 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1923.csv.gz
# -rw-r--r--   8 jsw93 jsw93   42037247 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1924.csv.gz
# -rw-r--r--   8 jsw93 jsw93   42301554 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1925.csv.gz
# -rw-r--r--   8 jsw93 jsw93   43495376 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1926.csv.gz
# -rw-r--r--   8 jsw93 jsw93   44260746 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1927.csv.gz
# -rw-r--r--   8 jsw93 jsw93   44786566 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1928.csv.gz
# -rw-r--r--   8 jsw93 jsw93   45743048 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1929.csv.gz
# -rw-r--r--   8 jsw93 jsw93   47123833 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1930.csv.gz
# -rw-r--r--   8 jsw93 jsw93   48686313 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1931.csv.gz
# -rw-r--r--   8 jsw93 jsw93   49739499 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1932.csv.gz
# -rw-r--r--   8 jsw93 jsw93   50189099 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1933.csv.gz
# -rw-r--r--   8 jsw93 jsw93   50511003 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1934.csv.gz
# -rw-r--r--   8 jsw93 jsw93   51471580 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1935.csv.gz
# -rw-r--r--   8 jsw93 jsw93   54582408 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1936.csv.gz
# -rw-r--r--   8 jsw93 jsw93   55921259 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1937.csv.gz
# -rw-r--r--   8 jsw93 jsw93   57039771 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1938.csv.gz
# -rw-r--r--   8 jsw93 jsw93   58779713 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1939.csv.gz
# -rw-r--r--   8 jsw93 jsw93   60994116 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1940.csv.gz
# -rw-r--r--   8 jsw93 jsw93   62866147 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1941.csv.gz
# -rw-r--r--   8 jsw93 jsw93   64941636 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1942.csv.gz
# -rw-r--r--   8 jsw93 jsw93   65746155 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1943.csv.gz
# -rw-r--r--   8 jsw93 jsw93   67455968 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1944.csv.gz
# -rw-r--r--   8 jsw93 jsw93   69900178 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1945.csv.gz
# -rw-r--r--   8 jsw93 jsw93   70349060 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1946.csv.gz
# -rw-r--r--   8 jsw93 jsw93   72082555 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1947.csv.gz
# -rw-r--r--   8 jsw93 jsw93   85868987 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1948.csv.gz
# -rw-r--r--   8 jsw93 jsw93   98267906 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1949.csv.gz
# -rw-r--r--   8 jsw93 jsw93  101263335 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1950.csv.gz
# -rw-r--r--   8 jsw93 jsw93  104446527 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1951.csv.gz
# -rw-r--r--   8 jsw93 jsw93  105808236 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1952.csv.gz
# -rw-r--r--   8 jsw93 jsw93  107270071 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1953.csv.gz
# -rw-r--r--   8 jsw93 jsw93  109267879 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1954.csv.gz
# -rw-r--r--   8 jsw93 jsw93  111596126 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1955.csv.gz
# -rw-r--r--   8 jsw93 jsw93  113749026 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1956.csv.gz
# -rw-r--r--   8 jsw93 jsw93  116373781 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1957.csv.gz
# -rw-r--r--   8 jsw93 jsw93  117509520 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1958.csv.gz
# -rw-r--r--   8 jsw93 jsw93  119859615 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1959.csv.gz
# -rw-r--r--   8 jsw93 jsw93  122200860 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1960.csv.gz
# -rw-r--r--   8 jsw93 jsw93  125967590 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1961.csv.gz
# -rw-r--r--   8 jsw93 jsw93  128646473 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1962.csv.gz
# -rw-r--r--   8 jsw93 jsw93  131584133 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1963.csv.gz
# -rw-r--r--   8 jsw93 jsw93  132546975 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1964.csv.gz
# -rw-r--r--   8 jsw93 jsw93  136835341 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1965.csv.gz
# -rw-r--r--   8 jsw93 jsw93  138635295 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1966.csv.gz
# -rw-r--r--   8 jsw93 jsw93  139954484 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1967.csv.gz
# -rw-r--r--   8 jsw93 jsw93  139531533 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1968.csv.gz
# -rw-r--r--   8 jsw93 jsw93  141312961 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1969.csv.gz
# -rw-r--r--   8 jsw93 jsw93  142164080 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1970.csv.gz
# -rw-r--r--   8 jsw93 jsw93  136925259 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1971.csv.gz
# -rw-r--r--   8 jsw93 jsw93  136002558 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1972.csv.gz
# -rw-r--r--   8 jsw93 jsw93  142460798 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1973.csv.gz
# -rw-r--r--   8 jsw93 jsw93  143641019 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1974.csv.gz
# -rw-r--r--   8 jsw93 jsw93  143118648 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1975.csv.gz
# -rw-r--r--   8 jsw93 jsw93  142908322 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1976.csv.gz
# -rw-r--r--   8 jsw93 jsw93  142708864 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1977.csv.gz
# -rw-r--r--   8 jsw93 jsw93  142882161 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1978.csv.gz
# -rw-r--r--   8 jsw93 jsw93  143163174 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1979.csv.gz
# -rw-r--r--   8 jsw93 jsw93  143519732 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1980.csv.gz
# -rw-r--r--   8 jsw93 jsw93  146434968 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1981.csv.gz
# -rw-r--r--   8 jsw93 jsw93  148208551 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1982.csv.gz
# -rw-r--r--   8 jsw93 jsw93  149574746 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1983.csv.gz
# -rw-r--r--   8 jsw93 jsw93  148106739 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1984.csv.gz
# -rw-r--r--   8 jsw93 jsw93  146541086 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1985.csv.gz
# -rw-r--r--   8 jsw93 jsw93  145614285 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1986.csv.gz
# -rw-r--r--   8 jsw93 jsw93  145664391 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1987.csv.gz
# -rw-r--r--   8 jsw93 jsw93  146418540 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1988.csv.gz
# -rw-r--r--   8 jsw93 jsw93  146879508 2024-08-07 01:39 hdfs:///data/ghcnd/daily/1989.csv.gz
# -rw-r--r--   8 jsw93 jsw93  147026774 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1990.csv.gz
# -rw-r--r--   8 jsw93 jsw93  147663667 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1991.csv.gz
# -rw-r--r--   8 jsw93 jsw93  147869832 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1992.csv.gz
# -rw-r--r--   8 jsw93 jsw93  146729098 2024-08-07 01:42 hdfs:///data/ghcnd/daily/1993.csv.gz
# -rw-r--r--   8 jsw93 jsw93  145684034 2024-08-07 01:44 hdfs:///data/ghcnd/daily/1994.csv.gz
# -rw-r--r--   8 jsw93 jsw93  145359752 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1995.csv.gz
# -rw-r--r--   8 jsw93 jsw93  145658563 2024-08-07 01:43 hdfs:///data/ghcnd/daily/1996.csv.gz
# -rw-r--r--   8 jsw93 jsw93  144446626 2024-08-07 01:40 hdfs:///data/ghcnd/daily/1997.csv.gz
# -rw-r--r--   8 jsw93 jsw93  147712042 2024-08-07 01:38 hdfs:///data/ghcnd/daily/1998.csv.gz
# -rw-r--r--   8 jsw93 jsw93  150446490 2024-08-07 01:41 hdfs:///data/ghcnd/daily/1999.csv.gz
# -rw-r--r--   8 jsw93 jsw93  152408599 2024-08-07 01:44 hdfs:///data/ghcnd/daily/2000.csv.gz
# -rw-r--r--   8 jsw93 jsw93  154826180 2024-08-07 01:43 hdfs:///data/ghcnd/daily/2001.csv.gz
# -rw-r--r--   8 jsw93 jsw93  156370434 2024-08-07 01:41 hdfs:///data/ghcnd/daily/2002.csv.gz
# -rw-r--r--   8 jsw93 jsw93  159878430 2024-08-07 01:39 hdfs:///data/ghcnd/daily/2003.csv.gz
# -rw-r--r--   8 jsw93 jsw93  162161295 2024-08-07 01:39 hdfs:///data/ghcnd/daily/2004.csv.gz
# -rw-r--r--   8 jsw93 jsw93  159008191 2024-08-07 01:43 hdfs:///data/ghcnd/daily/2005.csv.gz
# -rw-r--r--   8 jsw93 jsw93  165272645 2024-08-07 01:41 hdfs:///data/ghcnd/daily/2006.csv.gz
# -rw-r--r--   8 jsw93 jsw93  168113634 2024-08-07 01:43 hdfs:///data/ghcnd/daily/2007.csv.gz
# -rw-r--r--   8 jsw93 jsw93  175364525 2024-08-07 01:42 hdfs:///data/ghcnd/daily/2008.csv.gz
# -rw-r--r--   8 jsw93 jsw93  178179012 2024-08-07 01:42 hdfs:///data/ghcnd/daily/2009.csv.gz
# -rw-r--r--   8 jsw93 jsw93  179809093 2024-08-07 01:41 hdfs:///data/ghcnd/daily/2010.csv.gz
# -rw-r--r--   8 jsw93 jsw93  170536066 2024-08-07 01:39 hdfs:///data/ghcnd/daily/2011.csv.gz
# -rw-r--r--   8 jsw93 jsw93  168122525 2024-08-07 01:39 hdfs:///data/ghcnd/daily/2012.csv.gz
# -rw-r--r--   8 jsw93 jsw93  163476625 2024-08-07 01:40 hdfs:///data/ghcnd/daily/2013.csv.gz
# -rw-r--r--   8 jsw93 jsw93  161943389 2024-08-07 01:41 hdfs:///data/ghcnd/daily/2014.csv.gz
# -rw-r--r--   8 jsw93 jsw93  164424331 2024-08-07 01:40 hdfs:///data/ghcnd/daily/2015.csv.gz
# -rw-r--r--   8 jsw93 jsw93  165799325 2024-08-07 01:42 hdfs:///data/ghcnd/daily/2016.csv.gz
# -rw-r--r--   8 jsw93 jsw93  165395734 2024-08-07 01:43 hdfs:///data/ghcnd/daily/2017.csv.gz
# -rw-r--r--   8 jsw93 jsw93  165492857 2024-08-07 01:41 hdfs:///data/ghcnd/daily/2018.csv.gz
# -rw-r--r--   8 jsw93 jsw93  164296030 2024-08-07 01:40 hdfs:///data/ghcnd/daily/2019.csv.gz
# -rw-r--r--   8 jsw93 jsw93  165204327 2024-08-07 01:43 hdfs:///data/ghcnd/daily/2020.csv.gz
# -rw-r--r--   8 jsw93 jsw93  168079283 2024-08-07 01:38 hdfs:///data/ghcnd/daily/2021.csv.gz
# -rw-r--r--   8 jsw93 jsw93  168959151 2024-08-07 01:42 hdfs:///data/ghcnd/daily/2022.csv.gz
# -rw-r--r--   8 jsw93 jsw93  168357302 2024-08-07 01:41 hdfs:///data/ghcnd/daily/2023.csv.gz
# -rw-r--r--   8 jsw93 jsw93   88831735 2024-08-07 01:42 hdfs:///data/ghcnd/daily/2024.csv.gz

# %%
# Get the disk usage of the daily directory 
! hdfs dfs -du -h hdfs:///data/ghcnd/daily/
# Out:
# 1.8 M    14.5 M    hdfs:///data/ghcnd/daily/1750.csv.gz
# 3.3 K    26.2 K    hdfs:///data/ghcnd/daily/1763.csv.gz
# 3.2 K    26.0 K    hdfs:///data/ghcnd/daily/1764.csv.gz
# 3.3 K    26.1 K    hdfs:///data/ghcnd/daily/1765.csv.gz
# 3.3 K    26.1 K    hdfs:///data/ghcnd/daily/1766.csv.gz
# 3.3 K    26.2 K    hdfs:///data/ghcnd/daily/1767.csv.gz
# 3.2 K    26.0 K    hdfs:///data/ghcnd/daily/1768.csv.gz
# 3.3 K    26.7 K    hdfs:///data/ghcnd/daily/1769.csv.gz
# 3.3 K    26.2 K    hdfs:///data/ghcnd/daily/1770.csv.gz
# 3.3 K    26.4 K    hdfs:///data/ghcnd/daily/1771.csv.gz
# 3.3 K    26.7 K    hdfs:///data/ghcnd/daily/1772.csv.gz
# 3.3 K    26.3 K    hdfs:///data/ghcnd/daily/1773.csv.gz
# 3.3 K    26.5 K    hdfs:///data/ghcnd/daily/1774.csv.gz
# 6.2 K    49.7 K    hdfs:///data/ghcnd/daily/1775.csv.gz
# 6.3 K    50.2 K    hdfs:///data/ghcnd/daily/1776.csv.gz
# 6.3 K    50.2 K    hdfs:///data/ghcnd/daily/1777.csv.gz
# 6.1 K    48.8 K    hdfs:///data/ghcnd/daily/1778.csv.gz
# 6 K      48 K      hdfs:///data/ghcnd/daily/1779.csv.gz
# 6.1 K    48.8 K    hdfs:///data/ghcnd/daily/1780.csv.gz
# 7.6 K    60.9 K    hdfs:///data/ghcnd/daily/1781.csv.gz
# 7.6 K    61 K      hdfs:///data/ghcnd/daily/1782.csv.gz
# 7.7 K    61.9 K    hdfs:///data/ghcnd/daily/1783.csv.gz
# 7.8 K    62.1 K    hdfs:///data/ghcnd/daily/1784.csv.gz
# 7.6 K    61.0 K    hdfs:///data/ghcnd/daily/1785.csv.gz
# 7.7 K    61.6 K    hdfs:///data/ghcnd/daily/1786.csv.gz
# 6.2 K    49.5 K    hdfs:///data/ghcnd/daily/1787.csv.gz
# 6.2 K    50.0 K    hdfs:///data/ghcnd/daily/1788.csv.gz
# 7.6 K    60.7 K    hdfs:///data/ghcnd/daily/1789.csv.gz
# 7.6 K    60.8 K    hdfs:///data/ghcnd/daily/1790.csv.gz
# 7.6 K    60.4 K    hdfs:///data/ghcnd/daily/1791.csv.gz
# 7.6 K    61.0 K    hdfs:///data/ghcnd/daily/1792.csv.gz
# 6.2 K    49.5 K    hdfs:///data/ghcnd/daily/1793.csv.gz
# 7.6 K    60.7 K    hdfs:///data/ghcnd/daily/1794.csv.gz
# 7.7 K    61.3 K    hdfs:///data/ghcnd/daily/1795.csv.gz
# 7.6 K    61.1 K    hdfs:///data/ghcnd/daily/1796.csv.gz
# 9.0 K    72.2 K    hdfs:///data/ghcnd/daily/1797.csv.gz
# 9.1 K    72.6 K    hdfs:///data/ghcnd/daily/1798.csv.gz
# 6.2 K    49.6 K    hdfs:///data/ghcnd/daily/1799.csv.gz
# 7.6 K    60.8 K    hdfs:///data/ghcnd/daily/1800.csv.gz
# 7.6 K    60.9 K    hdfs:///data/ghcnd/daily/1801.csv.gz
# 9.0 K    71.8 K    hdfs:///data/ghcnd/daily/1802.csv.gz
# 7.7 K    61.7 K    hdfs:///data/ghcnd/daily/1803.csv.gz
# 8.5 K    68.2 K    hdfs:///data/ghcnd/daily/1804.csv.gz
# 8.7 K    69.5 K    hdfs:///data/ghcnd/daily/1805.csv.gz
# 8.4 K    67.2 K    hdfs:///data/ghcnd/daily/1806.csv.gz
# 8.5 K    68.2 K    hdfs:///data/ghcnd/daily/1807.csv.gz
# 8.7 K    69.8 K    hdfs:///data/ghcnd/daily/1808.csv.gz
# 8.6 K    68.6 K    hdfs:///data/ghcnd/daily/1809.csv.gz
# 8.6 K    69.0 K    hdfs:///data/ghcnd/daily/1810.csv.gz
# 8.7 K    69.8 K    hdfs:///data/ghcnd/daily/1811.csv.gz
# 8.8 K    70.3 K    hdfs:///data/ghcnd/daily/1812.csv.gz
# 9.0 K    72.4 K    hdfs:///data/ghcnd/daily/1813.csv.gz
# 10.6 K   84.6 K    hdfs:///data/ghcnd/daily/1814.csv.gz
# 13.6 K   108.5 K   hdfs:///data/ghcnd/daily/1815.csv.gz
# 13.5 K   108.3 K   hdfs:///data/ghcnd/daily/1816.csv.gz
# 13.4 K   107.5 K   hdfs:///data/ghcnd/daily/1817.csv.gz
# 13.4 K   107.5 K   hdfs:///data/ghcnd/daily/1818.csv.gz
# 13.4 K   107.0 K   hdfs:///data/ghcnd/daily/1819.csv.gz
# 13.7 K   109.4 K   hdfs:///data/ghcnd/daily/1820.csv.gz
# 13.5 K   107.8 K   hdfs:///data/ghcnd/daily/1821.csv.gz
# 13.7 K   109.8 K   hdfs:///data/ghcnd/daily/1822.csv.gz
# 14.4 K   115.2 K   hdfs:///data/ghcnd/daily/1823.csv.gz
# 17.6 K   140.9 K   hdfs:///data/ghcnd/daily/1824.csv.gz
# 17.7 K   141.4 K   hdfs:///data/ghcnd/daily/1825.csv.gz
# 18.0 K   143.8 K   hdfs:///data/ghcnd/daily/1826.csv.gz
# 20.4 K   162.9 K   hdfs:///data/ghcnd/daily/1827.csv.gz
# 20.5 K   163.9 K   hdfs:///data/ghcnd/daily/1828.csv.gz
# 20.6 K   165.2 K   hdfs:///data/ghcnd/daily/1829.csv.gz
# 20.8 K   166.5 K   hdfs:///data/ghcnd/daily/1830.csv.gz
# 20.8 K   166.6 K   hdfs:///data/ghcnd/daily/1831.csv.gz
# 21.9 K   175.3 K   hdfs:///data/ghcnd/daily/1832.csv.gz
# 26.6 K   213.2 K   hdfs:///data/ghcnd/daily/1833.csv.gz
# 26.5 K   211.7 K   hdfs:///data/ghcnd/daily/1834.csv.gz
# 26.9 K   215.0 K   hdfs:///data/ghcnd/daily/1835.csv.gz
# 29.1 K   232.9 K   hdfs:///data/ghcnd/daily/1836.csv.gz
# 28.7 K   229.2 K   hdfs:///data/ghcnd/daily/1837.csv.gz
# 31.0 K   247.7 K   hdfs:///data/ghcnd/daily/1838.csv.gz
# 28.9 K   231.1 K   hdfs:///data/ghcnd/daily/1839.csv.gz
# 35.1 K   281.2 K   hdfs:///data/ghcnd/daily/1840.csv.gz
# 36.1 K   289.0 K   hdfs:///data/ghcnd/daily/1841.csv.gz
# 38.5 K   308.1 K   hdfs:///data/ghcnd/daily/1842.csv.gz
# 38.5 K   307.8 K   hdfs:///data/ghcnd/daily/1843.csv.gz
# 42.3 K   338.4 K   hdfs:///data/ghcnd/daily/1844.csv.gz
# 46.0 K   368.0 K   hdfs:///data/ghcnd/daily/1845.csv.gz
# 43.6 K   348.8 K   hdfs:///data/ghcnd/daily/1846.csv.gz
# 45.1 K   360.8 K   hdfs:///data/ghcnd/daily/1847.csv.gz
# 44.0 K   351.9 K   hdfs:///data/ghcnd/daily/1848.csv.gz
# 46.3 K   370.1 K   hdfs:///data/ghcnd/daily/1849.csv.gz
# 46.4 K   371.5 K   hdfs:///data/ghcnd/daily/1850.csv.gz
# 53.7 K   429.9 K   hdfs:///data/ghcnd/daily/1851.csv.gz
# 57.5 K   459.9 K   hdfs:///data/ghcnd/daily/1852.csv.gz
# 58.2 K   465.9 K   hdfs:///data/ghcnd/daily/1853.csv.gz
# 57.9 K   463.0 K   hdfs:///data/ghcnd/daily/1854.csv.gz
# 63.4 K   506.9 K   hdfs:///data/ghcnd/daily/1855.csv.gz
# 74.5 K   596.0 K   hdfs:///data/ghcnd/daily/1856.csv.gz
# 81.2 K   649.4 K   hdfs:///data/ghcnd/daily/1857.csv.gz
# 112.8 K  902.6 K   hdfs:///data/ghcnd/daily/1858.csv.gz
# 125.7 K  1005.7 K  hdfs:///data/ghcnd/daily/1859.csv.gz
# 134.6 K  1.1 M     hdfs:///data/ghcnd/daily/1860.csv.gz
# 139.8 K  1.1 M     hdfs:///data/ghcnd/daily/1861.csv.gz
# 134.6 K  1.1 M     hdfs:///data/ghcnd/daily/1862.csv.gz
# 151.4 K  1.2 M     hdfs:///data/ghcnd/daily/1863.csv.gz
# 155.7 K  1.2 M     hdfs:///data/ghcnd/daily/1864.csv.gz
# 156.8 K  1.2 M     hdfs:///data/ghcnd/daily/1865.csv.gz
# 203.3 K  1.6 M     hdfs:///data/ghcnd/daily/1866.csv.gz
# 243.5 K  1.9 M     hdfs:///data/ghcnd/daily/1867.csv.gz
# 256.1 K  2.0 M     hdfs:///data/ghcnd/daily/1868.csv.gz
# 296.3 K  2.3 M     hdfs:///data/ghcnd/daily/1869.csv.gz
# 339.9 K  2.7 M     hdfs:///data/ghcnd/daily/1870.csv.gz
# 447.5 K  3.5 M     hdfs:///data/ghcnd/daily/1871.csv.gz
# 607.3 K  4.7 M     hdfs:///data/ghcnd/daily/1872.csv.gz
# 679.7 K  5.3 M     hdfs:///data/ghcnd/daily/1873.csv.gz
# 760.5 K  5.9 M     hdfs:///data/ghcnd/daily/1874.csv.gz
# 826.7 K  6.5 M     hdfs:///data/ghcnd/daily/1875.csv.gz
# 896.1 K  7.0 M     hdfs:///data/ghcnd/daily/1876.csv.gz
# 999.5 K  7.8 M     hdfs:///data/ghcnd/daily/1877.csv.gz
# 1.2 M    9.3 M     hdfs:///data/ghcnd/daily/1878.csv.gz
# 1.3 M    10.6 M    hdfs:///data/ghcnd/daily/1879.csv.gz
# 1.7 M    13.4 M    hdfs:///data/ghcnd/daily/1880.csv.gz
# 2.0 M    16.0 M    hdfs:///data/ghcnd/daily/1881.csv.gz
# 2.3 M    18.2 M    hdfs:///data/ghcnd/daily/1882.csv.gz
# 2.5 M    20.1 M    hdfs:///data/ghcnd/daily/1883.csv.gz
# 3.0 M    24.0 M    hdfs:///data/ghcnd/daily/1884.csv.gz
# 3.4 M    27.3 M    hdfs:///data/ghcnd/daily/1885.csv.gz
# 3.7 M    29.9 M    hdfs:///data/ghcnd/daily/1886.csv.gz
# 4.2 M    33.6 M    hdfs:///data/ghcnd/daily/1887.csv.gz
# 4.5 M    36.2 M    hdfs:///data/ghcnd/daily/1888.csv.gz
# 4.9 M    39.3 M    hdfs:///data/ghcnd/daily/1889.csv.gz
# 5.4 M    42.9 M    hdfs:///data/ghcnd/daily/1890.csv.gz
# 5.6 M    44.9 M    hdfs:///data/ghcnd/daily/1891.csv.gz
# 6.5 M    51.8 M    hdfs:///data/ghcnd/daily/1892.csv.gz
# 11.9 M   95.5 M    hdfs:///data/ghcnd/daily/1893.csv.gz
# 12.8 M   102.1 M   hdfs:///data/ghcnd/daily/1894.csv.gz
# 13.8 M   110.3 M   hdfs:///data/ghcnd/daily/1895.csv.gz
# 14.9 M   118.9 M   hdfs:///data/ghcnd/daily/1896.csv.gz
# 16.1 M   128.4 M   hdfs:///data/ghcnd/daily/1897.csv.gz
# 16.8 M   134.0 M   hdfs:///data/ghcnd/daily/1898.csv.gz
# 17.4 M   139.3 M   hdfs:///data/ghcnd/daily/1899.csv.gz
# 18.6 M   148.9 M   hdfs:///data/ghcnd/daily/1900.csv.gz
# 23.7 M   189.3 M   hdfs:///data/ghcnd/daily/1901.csv.gz
# 24.6 M   196.4 M   hdfs:///data/ghcnd/daily/1902.csv.gz
# 25.1 M   200.5 M   hdfs:///data/ghcnd/daily/1903.csv.gz
# 25.9 M   207.0 M   hdfs:///data/ghcnd/daily/1904.csv.gz
# 27.2 M   217.8 M   hdfs:///data/ghcnd/daily/1905.csv.gz
# 27.8 M   222.6 M   hdfs:///data/ghcnd/daily/1906.csv.gz
# 28.5 M   228.1 M   hdfs:///data/ghcnd/daily/1907.csv.gz
# 29.2 M   233.5 M   hdfs:///data/ghcnd/daily/1908.csv.gz
# 30.7 M   245.8 M   hdfs:///data/ghcnd/daily/1909.csv.gz
# 31.8 M   254.1 M   hdfs:///data/ghcnd/daily/1910.csv.gz
# 32.9 M   263.3 M   hdfs:///data/ghcnd/daily/1911.csv.gz
# 34.2 M   273.2 M   hdfs:///data/ghcnd/daily/1912.csv.gz
# 35.1 M   280.4 M   hdfs:///data/ghcnd/daily/1913.csv.gz
# 36.2 M   289.5 M   hdfs:///data/ghcnd/daily/1914.csv.gz
# 37.3 M   298.3 M   hdfs:///data/ghcnd/daily/1915.csv.gz
# 38.6 M   308.5 M   hdfs:///data/ghcnd/daily/1916.csv.gz
# 38.8 M   310.2 M   hdfs:///data/ghcnd/daily/1917.csv.gz
# 37.9 M   303.0 M   hdfs:///data/ghcnd/daily/1918.csv.gz
# 37.4 M   299.5 M   hdfs:///data/ghcnd/daily/1919.csv.gz
# 37.7 M   301.3 M   hdfs:///data/ghcnd/daily/1920.csv.gz
# 37.9 M   303.3 M   hdfs:///data/ghcnd/daily/1921.csv.gz
# 38.6 M   308.8 M   hdfs:///data/ghcnd/daily/1922.csv.gz
# 39.3 M   314.4 M   hdfs:///data/ghcnd/daily/1923.csv.gz
# 40.1 M   320.7 M   hdfs:///data/ghcnd/daily/1924.csv.gz
# 40.3 M   322.7 M   hdfs:///data/ghcnd/daily/1925.csv.gz
# 41.5 M   331.8 M   hdfs:///data/ghcnd/daily/1926.csv.gz
# 42.2 M   337.7 M   hdfs:///data/ghcnd/daily/1927.csv.gz
# 42.7 M   341.7 M   hdfs:///data/ghcnd/daily/1928.csv.gz
# 43.6 M   349.0 M   hdfs:///data/ghcnd/daily/1929.csv.gz
# 44.9 M   359.5 M   hdfs:///data/ghcnd/daily/1930.csv.gz
# 46.4 M   371.4 M   hdfs:///data/ghcnd/daily/1931.csv.gz
# 47.4 M   379.5 M   hdfs:///data/ghcnd/daily/1932.csv.gz
# 47.9 M   382.9 M   hdfs:///data/ghcnd/daily/1933.csv.gz
# 48.2 M   385.4 M   hdfs:///data/ghcnd/daily/1934.csv.gz
# 49.1 M   392.7 M   hdfs:///data/ghcnd/daily/1935.csv.gz
# 52.1 M   416.4 M   hdfs:///data/ghcnd/daily/1936.csv.gz
# 53.3 M   426.6 M   hdfs:///data/ghcnd/daily/1937.csv.gz
# 54.4 M   435.2 M   hdfs:///data/ghcnd/daily/1938.csv.gz
# 56.1 M   448.5 M   hdfs:///data/ghcnd/daily/1939.csv.gz
# 58.2 M   465.3 M   hdfs:///data/ghcnd/daily/1940.csv.gz
# 60.0 M   479.6 M   hdfs:///data/ghcnd/daily/1941.csv.gz
# 61.9 M   495.5 M   hdfs:///data/ghcnd/daily/1942.csv.gz
# 62.7 M   501.6 M   hdfs:///data/ghcnd/daily/1943.csv.gz
# 64.3 M   514.6 M   hdfs:///data/ghcnd/daily/1944.csv.gz
# 66.7 M   533.3 M   hdfs:///data/ghcnd/daily/1945.csv.gz
# 67.1 M   536.7 M   hdfs:///data/ghcnd/daily/1946.csv.gz
# 68.7 M   549.9 M   hdfs:///data/ghcnd/daily/1947.csv.gz
# 81.9 M   655.1 M   hdfs:///data/ghcnd/daily/1948.csv.gz
# 93.7 M   749.7 M   hdfs:///data/ghcnd/daily/1949.csv.gz
# 96.6 M   772.6 M   hdfs:///data/ghcnd/daily/1950.csv.gz
# 99.6 M   796.9 M   hdfs:///data/ghcnd/daily/1951.csv.gz
# 100.9 M  807.3 M   hdfs:///data/ghcnd/daily/1952.csv.gz
# 102.3 M  818.4 M   hdfs:///data/ghcnd/daily/1953.csv.gz
# 104.2 M  833.6 M   hdfs:///data/ghcnd/daily/1954.csv.gz
# 106.4 M  851.4 M   hdfs:///data/ghcnd/daily/1955.csv.gz
# 108.5 M  867.8 M   hdfs:///data/ghcnd/daily/1956.csv.gz
# 111.0 M  887.9 M   hdfs:///data/ghcnd/daily/1957.csv.gz
# 112.1 M  896.5 M   hdfs:///data/ghcnd/daily/1958.csv.gz
# 114.3 M  914.5 M   hdfs:///data/ghcnd/daily/1959.csv.gz
# 116.5 M  932.3 M   hdfs:///data/ghcnd/daily/1960.csv.gz
# 120.1 M  961.1 M   hdfs:///data/ghcnd/daily/1961.csv.gz
# 122.7 M  981.5 M   hdfs:///data/ghcnd/daily/1962.csv.gz
# 125.5 M  1003.9 M  hdfs:///data/ghcnd/daily/1963.csv.gz
# 126.4 M  1011.3 M  hdfs:///data/ghcnd/daily/1964.csv.gz
# 130.5 M  1.0 G     hdfs:///data/ghcnd/daily/1965.csv.gz
# 132.2 M  1.0 G     hdfs:///data/ghcnd/daily/1966.csv.gz
# 133.5 M  1.0 G     hdfs:///data/ghcnd/daily/1967.csv.gz
# 133.1 M  1.0 G     hdfs:///data/ghcnd/daily/1968.csv.gz
# 134.8 M  1.1 G     hdfs:///data/ghcnd/daily/1969.csv.gz
# 135.6 M  1.1 G     hdfs:///data/ghcnd/daily/1970.csv.gz
# 130.6 M  1.0 G     hdfs:///data/ghcnd/daily/1971.csv.gz
# 129.7 M  1.0 G     hdfs:///data/ghcnd/daily/1972.csv.gz
# 135.9 M  1.1 G     hdfs:///data/ghcnd/daily/1973.csv.gz
# 137.0 M  1.1 G     hdfs:///data/ghcnd/daily/1974.csv.gz
# 136.5 M  1.1 G     hdfs:///data/ghcnd/daily/1975.csv.gz
# 136.3 M  1.1 G     hdfs:///data/ghcnd/daily/1976.csv.gz
# 136.1 M  1.1 G     hdfs:///data/ghcnd/daily/1977.csv.gz
# 136.3 M  1.1 G     hdfs:///data/ghcnd/daily/1978.csv.gz
# 136.5 M  1.1 G     hdfs:///data/ghcnd/daily/1979.csv.gz
# 136.9 M  1.1 G     hdfs:///data/ghcnd/daily/1980.csv.gz
# 139.7 M  1.1 G     hdfs:///data/ghcnd/daily/1981.csv.gz
# 141.3 M  1.1 G     hdfs:///data/ghcnd/daily/1982.csv.gz
# 142.6 M  1.1 G     hdfs:///data/ghcnd/daily/1983.csv.gz
# 141.2 M  1.1 G     hdfs:///data/ghcnd/daily/1984.csv.gz
# 139.8 M  1.1 G     hdfs:///data/ghcnd/daily/1985.csv.gz
# 138.9 M  1.1 G     hdfs:///data/ghcnd/daily/1986.csv.gz
# 138.9 M  1.1 G     hdfs:///data/ghcnd/daily/1987.csv.gz
# 139.6 M  1.1 G     hdfs:///data/ghcnd/daily/1988.csv.gz
# 140.1 M  1.1 G     hdfs:///data/ghcnd/daily/1989.csv.gz
# 140.2 M  1.1 G     hdfs:///data/ghcnd/daily/1990.csv.gz
# 140.8 M  1.1 G     hdfs:///data/ghcnd/daily/1991.csv.gz
# 141.0 M  1.1 G     hdfs:///data/ghcnd/daily/1992.csv.gz
# 139.9 M  1.1 G     hdfs:///data/ghcnd/daily/1993.csv.gz
# 138.9 M  1.1 G     hdfs:///data/ghcnd/daily/1994.csv.gz
# 138.6 M  1.1 G     hdfs:///data/ghcnd/daily/1995.csv.gz
# 138.9 M  1.1 G     hdfs:///data/ghcnd/daily/1996.csv.gz
# 137.8 M  1.1 G     hdfs:///data/ghcnd/daily/1997.csv.gz
# 140.9 M  1.1 G     hdfs:///data/ghcnd/daily/1998.csv.gz
# 143.5 M  1.1 G     hdfs:///data/ghcnd/daily/1999.csv.gz
# 145.3 M  1.1 G     hdfs:///data/ghcnd/daily/2000.csv.gz
# 147.7 M  1.2 G     hdfs:///data/ghcnd/daily/2001.csv.gz
# 149.1 M  1.2 G     hdfs:///data/ghcnd/daily/2002.csv.gz
# 152.5 M  1.2 G     hdfs:///data/ghcnd/daily/2003.csv.gz
# 154.6 M  1.2 G     hdfs:///data/ghcnd/daily/2004.csv.gz
# 151.6 M  1.2 G     hdfs:///data/ghcnd/daily/2005.csv.gz
# 157.6 M  1.2 G     hdfs:///data/ghcnd/daily/2006.csv.gz
# 160.3 M  1.3 G     hdfs:///data/ghcnd/daily/2007.csv.gz
# 167.2 M  1.3 G     hdfs:///data/ghcnd/daily/2008.csv.gz
# 169.9 M  1.3 G     hdfs:///data/ghcnd/daily/2009.csv.gz
# 171.5 M  1.3 G     hdfs:///data/ghcnd/daily/2010.csv.gz
# 162.6 M  1.3 G     hdfs:///data/ghcnd/daily/2011.csv.gz
# 160.3 M  1.3 G     hdfs:///data/ghcnd/daily/2012.csv.gz
# 155.9 M  1.2 G     hdfs:///data/ghcnd/daily/2013.csv.gz
# 154.4 M  1.2 G     hdfs:///data/ghcnd/daily/2014.csv.gz
# 156.8 M  1.2 G     hdfs:///data/ghcnd/daily/2015.csv.gz
# 158.1 M  1.2 G     hdfs:///data/ghcnd/daily/2016.csv.gz
# 157.7 M  1.2 G     hdfs:///data/ghcnd/daily/2017.csv.gz
# 157.8 M  1.2 G     hdfs:///data/ghcnd/daily/2018.csv.gz
# 156.7 M  1.2 G     hdfs:///data/ghcnd/daily/2019.csv.gz
# 157.6 M  1.2 G     hdfs:///data/ghcnd/daily/2020.csv.gz
# 160.3 M  1.3 G     hdfs:///data/ghcnd/daily/2021.csv.gz
# 161.1 M  1.3 G     hdfs:///data/ghcnd/daily/2022.csv.gz
# 160.6 M  1.3 G     hdfs:///data/ghcnd/daily/2023.csv.gz
# 84.7 M   677.7 M   hdfs:///data/ghcnd/daily/2024.csv.gz

# %%
# Count the number of files in daily folder 
! hdfs dfs -count hdfs:///data/ghcnd/daily
# Out:
#            1          263        13348547980 hdfs:///data/ghcnd/daily

# %% [markdown]
# ##### There 263 files in daily directory  from 1750 - 2024

# %% [markdown]
# #### b.2 How does the size of the data change?

# %%
# In order to interpret how the size change over years, we need to transform the data to csv and plot it 
# In this case, we only need to transfer the column 5 and column 8 for plotting 
# ! hdfs dfs -du -h hdfs:///data/ghcnd/daily | awk 'BEGIN {OFS=","} {print $1, $2, $3, $4, $5}' > daily_data.csv
! hdfs dfs -ls hdfs:///data/ghcnd/daily | awk 'BEGIN {OFS=","} {print $5, $8}' > daily_data_1.csv

# %%
# Load the dataset had just converted to CSV file 
import pandas as pd 
daily_data = pd.read_csv("daily_data_1.csv")

# Print several rows
daily_data.head()
# Out:
#       Size                                  File
# 0  1897634  hdfs:///data/ghcnd/daily/1750.csv.gz
# 1     3358  hdfs:///data/ghcnd/daily/1763.csv.gz
# 2     3327  hdfs:///data/ghcnd/daily/1764.csv.gz
# 3     3335  hdfs:///data/ghcnd/daily/1765.csv.gz
# 4     3344  hdfs:///data/ghcnd/daily/1766.csv.gz

# %%
import re 

# Write the function to extract the year from file column 
def extract_year(data):
    "Function to extract year from file path"
    match = re.search(r'/(\d{4})\.csv\.gz$', data)
    return int(match.group(1)) if match else None

# Apply the function to extract year
daily_data["Year"] = daily_data['File'].apply(extract_year)

# Print out the data after extract 
daily_data.head()
# Out:
#       Size                                  File  Year
# 0  1897634  hdfs:///data/ghcnd/daily/1750.csv.gz  1750
# 1     3358  hdfs:///data/ghcnd/daily/1763.csv.gz  1763
# 2     3327  hdfs:///data/ghcnd/daily/1764.csv.gz  1764
# 3     3335  hdfs:///data/ghcnd/daily/1765.csv.gz  1765
# 4     3344  hdfs:///data/ghcnd/daily/1766.csv.gz  1766

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# Define your custom format function
def custom_format(value, tick_number):
    return f'{int(value):,}'

# Plotting
plt.figure(figsize=(14, 6))

# Subplot: Logged Data
logged_size = np.log(daily_data['Size'])
plt.plot(daily_data['Year'], logged_size, linestyle='--', color='blue')
plt.title('Logged Data Size From 1750 - 2024')
plt.xlabel('Year')
plt.ylabel('Log of Total Size')

# Set x-axis ticks with a step size of 20
ax = plt.gca()  # Get the current axis
ax.xaxis.set_major_locator(ticker.MultipleLocator(20))
ax.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot the data to see how the size of data change over time

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define your custom format function
def custom_format(value, tick_number):
    return f'{int(value):,}'

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(daily_data['Year'], daily_data['Size'], linestyle='-')
plt.title('Change in Data Size From 1750 - 2024')
plt.xlabel('Year')
plt.ylabel('Total Size (in Bytes)')

# Apply the custom formatter to the y-axis
ax = plt.gca()  # Get the current axis
ax.yaxis.set_major_formatter(ticker.FuncFormatter(custom_format))

# Set x-axis ticks with a step size of 2
ax.xaxis.set_major_locator(ticker.MultipleLocator(20))

plt.grid(True)
# Save the plot as an image file
#image_filename = 'Data_Size_Over_Years.png'
#plt.savefig(image_filename, format='png', dpi=300)  # Save as PNG with 300 DPI

# Show the plot
plt.show()

# %% [markdown]
# ### Take the logged

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# Define your custom format function
def custom_format(value, tick_number):
    return f'{int(value):,}'

# Plotting
plt.figure(figsize=(14, 6))

# Subplot 1: Original Data
plt.subplot(1, 2, 1)
plt.plot(daily_data['Year'], daily_data['Size'], linestyle='-')
plt.title('Original Data Size From 1750 - 2024')
plt.xlabel('Year')
plt.ylabel('Total Size (in Bytes)')

# Apply the custom formatter to the y-axis
ax1 = plt.gca()  # Get the current axis
ax1.yaxis.set_major_formatter(ticker.FuncFormatter(custom_format))

# Set x-axis ticks with a step size of 20
ax1.xaxis.set_major_locator(ticker.MultipleLocator(20))
plt.grid(True)

# Subplot 2: Logged Data
plt.subplot(1, 2, 2)
logged_size = np.log(daily_data['Size'])
plt.plot(daily_data['Year'], logged_size, linestyle='-', color='orange')
plt.title('Logged Data Size From 1750 - 2024')
plt.xlabel('Year')
plt.ylabel('Log of Total Size')

# Set x-axis ticks with a step size of 20
ax2 = plt.gca()  # Get the current axis
ax2.xaxis.set_major_locator(ticker.MultipleLocator(20))
plt.grid(True)

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### c. What is the total size of all of the data, and how much of that is daily

# %% [markdown]
# #### c.1 What is the total size of all of the data

# %%
# using -du and -s provide a summary of disk usage for the entire directory 
! hdfs dfs -du -s -h hdfs:///data/ghcnd/
# Out:
# 12.5 G  99.8 G  hdfs:///data/ghcnd

# %%
# Get the disk usage of the daily directory to compare 
! hdfs dfs -du -s -h hdfs:///data/ghcnd/daily
# Out:
# 12.4 G  99.5 G  hdfs:///data/ghcnd/daily

# %%
# Get the disk usage of the entire ghcnd 
! hdfs dfs -du -h hdfs:///data/ghcnd/
# Out:
# 12.4 G  99.5 G   hdfs:///data/ghcnd/daily
# 3.6 K   28.6 K   hdfs:///data/ghcnd/ghcnd-countries.txt
# 33.2 M  265.4 M  hdfs:///data/ghcnd/ghcnd-inventory.txt
# 1.1 K   8.5 K    hdfs:///data/ghcnd/ghcnd-states.txt
# 10.5 M  84.0 M   hdfs:///data/ghcnd/ghcnd-stations.txt

# %% [markdown]
# ##### In order to summarize  the sizes of the datasets, we transform the disk usage data into the csv file

# %%
# List the sizes of all directories/files in ghcnd and store it to a local csv
! hdfs dfs -du -h hdfs:///data/ghcnd/ | awk '{print $1, $2, $3, $4, $5}' > dataset_sizes.csv

# %%
# Load the dataset that had just converted to csv 
dataset_sizes = pd.read_csv("dataset_sizes.csv")

# Print the data 
dataset_sizes.head()
# Out:
#   Actual_Size Disk_Space_Usage   Datasets
# 0      12.4 G           99.5 G      Daily
# 1      3.6 K            28.6 K  Countries
# 2      33.2 M          265.4 M  Inventory
# 3      1.1 K             8.5 K     States
# 4     10.5 M            84.0 M   Stations

# %% [markdown]
# #### Since the dataset_sizes have several size unit such as:
# #### G : Gigabytes
# #### K : Kilobyte
# #### M : Megabyte
# #### In order to have a consistent unit, we need to convert the size into a consistent unit
# #### Here, we will convert the actual size into Kilobyte(KB)

# %%
# Write the function to convert the size to Kilobyte 
def convert_to_kb(size_str):
    "Write a function to convert the actual size to kilobyte"
    # Normalize the input 
    size_str = size_str.strip().upper()
    if size_str.endswith("B"):
        size = float(size_str[:-1].strip())
        return size / 1024 #convert bytes to kilobytes 
    elif size_str.endswith("K"):
        size = float(size_str[:-1].strip())
        return size # Already in kilobytes
    elif size_str.endswith("M"):
        size = float(size_str[:-1].strip())
        return size * 1024 # convert megabytes to kilobytes 
    elif size_str.endswith("G"):
        size = float(size_str[:-1].strip())
        return size * 1024 * 1024 # convert gigabytes to kilobytes 
    else:
        raise ValueError(f"Unknown size unit in '{size_str}'")
        
# Apply the function to the data 
dataset_sizes['Size_in_KB'] = dataset_sizes['Actual_Size'].apply(convert_to_kb)

# Print the dataset_sizes
dataset_sizes.head()
# Out:
#   Actual_Size Disk_Space_Usage   Datasets  Size_in_KB
# 0      12.4 G           99.5 G      Daily  13002342.4
# 1      3.6 K            28.6 K  Countries         3.6
# 2      33.2 M          265.4 M  Inventory     33996.8
# 3      1.1 K             8.5 K     States         1.1
# 4     10.5 M            84.0 M   Stations     10752.0

# %% [markdown]
# #### c.2 How much of that is daily?
# #####  To know how many percent of this is daily we need to calculate the proportion of the total size
# #####  Find the proportion for each dataset

# %%
# Calculate the total size
total_size = dataset_sizes['Size_in_KB'].sum()

# Calculate the percentage of total size for each dataset 
dataset_sizes['Percentage_of_Total(%)'] = round((dataset_sizes['Size_in_KB'] / total_size) * 100,8)

# Print the dataset
dataset_sizes
# Out:
#   Actual_Size Disk_Space_Usage   Datasets  Size_in_KB  Percentage_of_Total(%)
# 0      12.4 G           99.5 G      Daily  13002342.4               99.656985
# 1      3.6 K            28.6 K  Countries         3.6                0.000028
# 2      33.2 M          265.4 M  Inventory     33996.8                0.260570
# 3      1.1 K             8.5 K     States         1.1                0.000008
# 4     10.5 M            84.0 M   Stations     10752.0                0.082409

# %% [markdown]
# ##### The daily data have a highest size in the dataset, which accounted for 99.65 % of all the datasets.

# %%
# Save the DataFrame to a CSV file
csv_filename = 'dataset_sizes_converted.csv'
dataset_sizes.to_csv(csv_filename, index=False)  # index=False to avoid writing row numbers

# %%
# Run this cell before closing the notebook or kill your spark application by hand using the link in the Spark UI

stop_spark()
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>kda115 (jupyter)</code> is under the completed applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li></ul>
